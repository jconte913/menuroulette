# %%
# The following are dictionaries containing ideas for dinner separated into different categories, and a list of lunch ideas

# %%
pastas = {
    "pasta carbonara" : ["pasta", "oil", "garlic", "salt", "rosemary", "bacon"],
    "lasagna" : ["no bake lasagna sheets", "tomato sauce", "ground beef", "hot italian sausage", "mozzarella", "parmesan"],    
	"pasta amatriciana" : ["pasta", "oil", "bacon", "onion", "tomato puree", "salt", "parmigiano"],
	"pasta with fava" : ["fava beans", "oil", "bacon", "onions", "pasta", "salt"],
    "pasta with pepper" : ["pasta", "bell pepper", "oil", "garlic", "onion", "bacon", "lemon juice", "sugar", "salt"],
	"pasta with egg" : ["egg", "pasta", "oil", "salt"],
    "baked lemon pasta" : ["spaghetti", "oil", "butter", "lemon", "garlic", "sour cream", "parsley", "parmigiano"],
    "linguine with white clam sauce" : ["linguine", "oil", "garlic", "minced clams, can", "parsley", "white wine", "lemon juice"],
    "pasta Alfredo" : ["butter", "heavy whipping cream", "garlic", "parmigiano"],
    "lemon chicken orzo soup" : ["celery", "carrot", "onion", "butter", "oil", "garlic", "flour", "stock", "chicken breasts", "orzo", "lemon juice", "parlsey"],
    "veggie lasagna" : ["onions", "mushrooms", "eggplant", "zucchini", "bell pepper", "lasagna sheets", "tomato sauce", "mozzarella"],
    "swedish meatballs" : ["stock", "heavy cream", "flour", "soy sauce", "dried rosemary", "frozen cooked meatballs", "egg noodles"],
    "orzo with parmegiano and basil" : ["butter", "orzo", "stock", "parmigiano", "fresh basil"],
    "lasagna soup" : ["oil", "italian sausage", "onion", "garlic", "oregano", "red pepper flakes", "tomato paste", "fire roasted diced tomatoes", "bay leaves", "stock", "fusilli pasta", "fresh basil", "ricotta", "parmigiano"],
    "pasta fritatta" : ["spaghetti", "egg", "sausage", "cheese"],
    "pasta with smoked salmon" : ["onion", "oil", "smoked salmon", "tomatoes", "brandy", "worchestershire sauce", "heavy cream", "parmigiano"],
    "penne alla vodka" : ["onion", "vodka", "heavy cream", "tomatoes", "oil"],
    "pasta with meat sauce" : ["pasta", "pork or beef stew meat", "tomato puree", "oil", "garlic", "onion", "basil", "oregano", "parsley"],
}

# %%
easy_meals = {
	"BLT" : ["good bread", "bacon", "tomato", "lettuce", "mayo"],
	"chicken cutlets with veg" : ["chicken", "bread crumbs", "egg", "oil", "salt", "veg"],
	"microwave meal" : ["amy's", "deep", "saffron road", "something new"],
	"steak and potatoes" : ["steak", "potatoes", "oil", "salt", "oregano", "garlic"],
	"burgers" : ["burger", "cheese", "pickles", "lettuce", "tomato", "mayo", "ketchup", "bioche buns"],
	"roasted chicken with veg" : ["chicken legs / thighs / quarters", "dried spices", "veg"],
	"quiche with veg" : [("supermarket quiche", "veg"),("pie crust", "bacon or ham", "onion", "fresh thyme", "gruyere", "eggs", "heavy cream", "nutmeg"), ("eggs", "heavy cream", "baby spinach", "bacon", "swiss cheese", "pie crust")],
    "oven baked chicken wings" : ["chicken wings", "baking powder", "oil"],
    "slow cooker pulled pork" : ["onions", "garlic", "stock", "brown sugar", "chili powder", "cumin", "cinnamon", "pork shoulder"],
    "instant pot butter chicken" : ["tomatoes", "garlic", "ginger", "tumeric", "cayenne pepper", "smoked paprika", "garam masala", "cumin", "boneless skinless chicken thighs", "butter", "heavy cream", "cilantro"],
    "oven roasted shrimp" : ["large shrimp", "oil", "garlic", "chile oil", "fresh thyme"],
    "marinated chicken breasts" : ["chicken breasts", "oil", "balsamic", "soy sauce", "worcestershire sauce", "lemon juice", "brown sugar", "dried rosemary", "dijon mustard", "garlic powder"],
    "shredded mexican chicken" : ["oil", "skinless chicken thighs", "stock", "green onions", "poblano", "cumin", "garlic powder", "chili powder", "paprika", "cayenne pepper", "tomato"],
    "chicken piccata" : ["boneless chicken breasts", "flour", "butter", "oil", "lemon juice", "stock", "capers", "parsley"],
    "carne asada" : ["flank steak", "oil", "limes", "garlic", "cilantro", "cumin", "chili powder"],
    "no bean chili" : ["bell peppers", "ground meat", "chipotles in adobo", "onion", "san marzano tomato", "rotel tomatoes", "bay leaves", "garlic", "cayenne pepper", "chili powder", "chipotle chili powder", "cumin"],
    "gruyere potato gratin" : ["red potatoes", "gruyere", "egg", "milk"],
    "slow cooker bacon cheese potatoes" : ["bacon", "onions", "potatoes", "cheddar cheese", "butter", "green onions"],
    "skirt steak marinated asian-style" : ["chili oil", "sesame oil", "rice wine vinegar", "garlic", "ginger", "lemongrass", "green onions", "soy sauce", "skirt steak", "jasmine rice"],
    "saltimbocca alla romana" : ["veal cutlets", "prosciutto", "fresh sage", "flour", "oil", "butter", "white wine", "stock", "lemon"],
    "chicken enchiladas" : ["onion", "garlic", "oil", "diced green chilies", "cooked chicken", "cream cheese", "monterrey jack cheese", "whipping cream", "flour or corn tortillas"],
    "swiss chard and potatoes" : ["swiss shard", "potatoes", "garlic", "oil"],
    "pork and potatoes" : ["pork butt or country pork ribs", "oil", "potatoes", "garlic", "oregano"],
    "salisbury steak" : ["ground beef", "onions", "sugar", "oil", "garlic", "tomato paste", "stock", "red wine", "thyme", "flour", "parsley", "green onion"]
}

# %%
intensive_meals = {
	"eggplant parm" : ["eggplant", "oil", "bread crumbs", "egg", "tomato sauce", "mozzarella"],
	"grilled veggies" : ["eggplant", "zucchini", "summer squash", "bell pepper", "mushroom", "onion", "oil", "balsamic", "basil", "fresh mozzarella"],
	"roast beef and mashed potatoes" : ["beef roast", "potatoes", "dill weed", "onion", "dried spices"],
	"roast chicken with veggies" : ["whole chicken", "oil", "dried spices", "veg"],
	"duck breasts" : ["duck breasts", "port", "cherries", "orange", "shallots"],
    "Marecella Hazan Bolognese" : ["onion", "celery", "carrot", "garlic", "ground beef", "oil", "red pepper flakes", "nutmeg", "white wine", "pureed tomato", "parmigiano rinds"],
    "Scottish Steak Pie" : ["oil", "flour", "stew beef", "onions", "stock", "puff pastry", "egg"],
    "potato pretzels" : ["russet potatoes", "flour", "parmigiano", "parsley", "garlic"],
    "birria de Res" : ["brisket", "tomatoes", "onion", "garlic", "ancho chiles", "new mexican chiles", "chipotles in adobo", "stock", "cumin", "oregano", "cinnamon", "clove", "salsa aguacate: avocado, lime, cilantro"],
    "chicken chile verde tostadas" : ["chicken breasts", "tomatillos", "poblano", "jalapenos", "onion", "garlic", "cilantro", "oregano", "cumin", "tostada", "refried beans", "queso fresco", "lime"],
    "oven brisket" : ["beef brisket", "brown sugar", "chili powder", "paprika", "dried mustard", "garlic powder", "onion powder", "dried thyme", "liquid smoke"],
    "general Tso's chicken" : ["egg", "soy sauce", "sugar", "boneless chicken thighs", "hoisin sauce", "unseasoned rice vinegar", "cornstarch", "sesame oil", "flour", "baking soda", "minced ginger", "red pepper flakes", "garlic", "green onions", "sesame seeds", "rice"],
    "hot and sour soup" : ["pork shoulder", "cornstarch", "oil", "red chili peppers", "dried lil flower", "wood ear mushrooms", "shiitake mushrooms", "dry tofu", "firm tofu", "bamboo shoots", "egg", "green onion", "stock", "sugar", "white pepper", "soy sauce", "sesame oil", "white vinegar"],
    "french onion soup" : ["butter", "onions", "garlic", "bay leaves", "thyme", "red wine", "flour", "stock", "gruyere", "baguette"],
    "duck breasts with citrus port cherry sauce" : ["duck breasts", "shallots", "ruby port", "orange juice", "pitted frozen black cherries"],
    "oven baked ribs" : ["baby back pork ribs", "cumin", "paprika", "garlic powder", "onion powder", "chili powder", "brown sugar", "cayenne pepper"],
    "rack of lamb" : ["lamb", "rosemary", "oil", "garlic", "thyme?"],
    "chicken with rice" : ["oil", "basil", "parlsey", "onion", "garlic", "oregano", "chicken legs or thighs"],
    "rice balls" : ["carolina rice", "parsley", "garlic", "parmigiano", "egg"],
    "stuffed eggplant" : ["italian eggplant", "parsley", "ground beef, tomatoes", "parmigiano", "bread crumbs", "garlic"],
    "chicken arrabiata" : ["chicken tenders", "flour", "egg", "tomato", "red pepper flakes", "garlic", "oil"],
    "easter lamb and potatoes" : ["lamb pieces", "onion", "garlic", "red potatoes", "rosemary", "oregano", "parsley"],
    "papocchia" : ["eggplant", "red potatoes", "red bell pepper", "onion", "garlic"],
    "broccoli rabe with cannellini beans" : ["broccoli rabe", "red or white cannellini beans", "oil", "garlic"],
    "pizza coperto" : ["pizza dough", "tomato", "red onion", "capers or anchovies", "oregano", "oil"]
}

# %%
fish = {
    "Jamaican fried snapper" : ["whole red snapper", "oil", "onion", "carrot", "garlic", "vinegar", "habanero pepper", "fresh thyme", "allspice berry", "brown sugar"],
    "shrimp and corn chowder" : ["bell pepper", "garlic", "onion", "tomatoes", "cumin", "smoked paprika", "stock", "heavy cream", "russet potatoes", "shrimp", "corn kernels", "parsley", "oregano"],
    "broiled salmon with herb mustard glaze" : ["garlic", "fresh rosemary", "fresh thyme", "white wine", "oil", "dijon mustard", "whole grain mustard", "salmon fillets", "lemon"],
    "steamed mussels with garlic and parlsey" : ["oil", "garlic", "crushed red pepper", "mussels", "white wine", "baguette", "parsley"],
    "bluefish" : ["bluefish fillet", "garlic", "parsley", "red pepper flakes", "oregano", "plum tomatoes"],
    "swordfish" : ["swordfish", "lemon", "oil", "parsley"],
    "calamari" : ["squid or sepia", "flour", "cornmeal or semolina", "oil", "lemon"]
}

# %%
lunch_options = [
    "leftover dinners",
    "cold cut sandwich",
    "fancy tuna salad"
    "chicken salad",
    "tuna salad sandwich",
    "boston lettuce avocado salad with lime dressing",
    "easy pasta salad with avocao", 
    "cobb salad",
    "winter rainbow panzanella salad",
    "china coast salad dressing on lettuce",
    "chipotle ranch dressing on chopped ingredients salad",
    "colorful strawberry arugula salad"
]
